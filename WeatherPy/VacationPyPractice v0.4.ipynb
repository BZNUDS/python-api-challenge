# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json

# Import API key
from api_keys import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# # Save as a csv
# # Note to avoid any issues later, use encoding="utf-8"
# weather_data.to_csv(output_data_file, encoding="utf-8", index=False)

# Input File (CSV)
input_data_path = "output_data/cities.csv"

# Read the mouse data and the study results
vacation_df = pd.read_csv(input_data_path)


# Display the data table for preview
# print("**************************************************************************")
# print("Reducing datafame size to 8 ([0:8] so need to remove the [0:8] at the end")
# vacation_df=vacation_df_input[0:8]
# print("**************************************************************************")
vacation_df
# Out:
#                   city      lat       lon   temp  TempMax  Humidity  \
# 0          new norfolk -42.7826  147.0587  19.96    22.64        38
# 1              mataura -46.1927  168.8643  23.44    23.44        55
# 2              peniche  39.3558   -9.3811  11.31    13.68        82
# 3            port said  31.2565   32.2841  12.93    12.93        67
# 4                ancud -41.8697  -73.8203   9.43     9.57        77
# ..                 ...      ...       ...    ...      ...       ...
# 575  sosnovo-ozerskoye  52.5249  111.5418 -17.24   -17.24        88
# 576          kilindoni  -7.9139   39.6668  27.45    27.45        77
# 577             tanout  14.9709    8.8879  14.49    14.49        11
# 578       vangaindrano -23.3500   47.6000  26.65    26.65        83
# 579              luwuk  -0.9516  122.7875  28.17    28.17        82
#
#      Cloudiness  Wind Speed
# 0             7        1.34
# 1            18        2.45
# 2            79        3.55
# 3            88       10.04
# 4            86        3.19
# ..          ...         ...
# 575         100        4.12
# 576         100        5.12
# 577          37        5.98
# 578          32        1.83
# 579         100        0.71
#
# [580 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
 # Store latitude and longitude in locations
locations = vacation_df[["lat", "lon"]]
# print("locations")
# print(locations)
# print()

# Fill NaN values and convert to float
humidity_weight = (vacation_df["Humidity"].astype(float)) /10
# print("**************************************************************************")
# print("Do I need to get rid of hardcoding that divides by 10 above")

# print("humidity_weight")
# print(humidity_weight)
# print()

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity_weight, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=2)


# Add layer
fig.add_layer(heat_layer)

# Save the figure
plt.savefig("output_data/lat_lon_hum.png")


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# print('vacation_df')
# print(vacation_df)
# Narrow down criteria to where my family would like to go on vacation (Hint: My wife Diane likes warmer weather:)
#Narrow down the DataFrame to find your ideal weather condition. For example:
# A max temperature lower than 37 Celsius (~98 degrees farneheight) but warmer than 22 (~72 farneheight)
# Wind speed less than or equal to 13kM (~20 mph) 

cities_high_humidity = []
cities_colder_weather = []
cities_high_wind = []

city_counter=0

# print('vacation_df["Humidity"]')
# print(vacation_df["Humidity"])
 
for city in vacation_df:
    if int(vacation_df["Humidity"][city_counter]) > 100:
              # Create a new list to track high humifity index values
              cities_high_humidity.append(city_counter)
    
    if (int(vacation_df["TempMax"][city_counter]) > 37 or int(vacation_df["TempMax"][city_counter]) < 22):
              # Create a new list to track high humifity index values
              cities_colder_weather.append(city_counter)
      
    if int(vacation_df["Wind Speed"][city_counter]) > 13:
              # Create a new list to track high humifity index values
              cities_high_wind.append(city_counter)
    
    city_counter+=1

# Merge/simplify list of unwanted cities based on criteria 
merged_removal_list = cities_high_humidity + cities_high_wind + cities_colder_weather + cities_high_wind
merged_removal_list = list(set(merged_removal_list))
# print("merged_removal_list after remoal of dups and reorder")
# print(merged_removal_list)
# print()
clean_vacation_df = vacation_df
clean_vacation_df=clean_vacation_df.drop(merged_removal_list, inplace=False) 

# drop all rows with any NaN and NaT values
clean_vacation_df = clean_vacation_df.dropna()
# print("clean_vacation_df after rdrop all rows with any NaN and NaT values")
# print(clean_vacation_df)
# print()

clean_vacation_df.reset_index(inplace=True)
print("clean_vacation_df after remoal of unwanted cities and reorder")
clean_vacation_df
# Out:
# clean_vacation_df after remoal of unwanted cities and reorder
#      index               city      lat       lon   temp  TempMax  Humidity  \
# 0        0        new norfolk -42.7826  147.0587  19.96    22.64        38
# 1        1            mataura -46.1927  168.8643  23.44    23.44        55
# 2        7          mahajanga -15.7167   46.3167  26.01    26.01        94
# 3        8       port lincoln -34.7333  135.8667  21.01    21.01        56
# 4        9      pacific grove  36.6177 -121.9166  14.58    17.12        51
# ..     ...                ...      ...       ...    ...      ...       ...
# 570    575  sosnovo-ozerskoye  52.5249  111.5418 -17.24   -17.24        88
# 571    576          kilindoni  -7.9139   39.6668  27.45    27.45        77
# 572    577             tanout  14.9709    8.8879  14.49    14.49        11
# 573    578       vangaindrano -23.3500   47.6000  26.65    26.65        83
# 574    579              luwuk  -0.9516  122.7875  28.17    28.17        82
#
#      Cloudiness  Wind Speed
# 0             7        1.34
# 1            18        2.45
# 2            40        2.06
# 3            13        6.46
# 4             0        2.06
# ..          ...         ...
# 570         100        4.12
# 571         100        5.12
# 572          37        5.98
# 573          32        1.83
# 574         100        0.71
#
# [575 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Store into variable named hotel_df
hotel_df = clean_vacation_df
print('**************************************************')
print('Limiting hotel_df to only hotel_df[0:5]')
hotel_df = hotel_df[0:5]
print('**************************************************')
#Add a "Hotel Name" column to the DataFrame
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
# **************************************************
# Limiting hotel_df to only hotel_df[0:5]
# **************************************************
# C:\Users\BZNORT~1\AppData\Local\Temp/ipykernel_2952/4186973828.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#    index           city      lat       lon   temp  TempMax  Humidity  \
# 0      0    new norfolk -42.7826  147.0587  19.96    22.64        38
# 1      1        mataura -46.1927  168.8643  23.44    23.44        55
# 2      7      mahajanga -15.7167   46.3167  26.01    26.01        94
# 3      8   port lincoln -34.7333  135.8667  21.01    21.01        56
# 4      9  pacific grove  36.6177 -121.9166  14.58    17.12        51
#
#    Cloudiness  Wind Speed Hotel Name
# 0           7        1.34
# 1          18        2.45
# 2          40        2.06
# 3          13        6.46
# 4           0        2.06

# %%
#Maybe remove at a later time, but save for now to discuss issue
# print("target_coordinates")
# print(target_coordinates)
# print(hotel_df.dtypes)
# print(hotel_df)
# print(hotel_df["lat"][0])
# print(hotel_df["lon"][0])
# # geocoordinates

# target_coordinates = "43.6187102, -116.2146068"
# #print(target_coordinates.dtypes)
# print("target_coordinates")
# print(target_coordinates)
# print()
# target_coordinates = ""
# #target_coordinates = str(hotel_df["lat"][0])+', '+ str(hotel_df["lon"][0])
# target_coordinates = '43.6187102' + ', ' + '-116.2146068'
# # target_coordinates.append(",") 
# #target_coordinates = hotel_df["lon"][0] 
# print("target_coordinates")
# print(target_coordinates)
# print()

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
#target_coordinates = "43.61, -116.21"
print("target_coordinates")
print(target_coordinates)
print()

# target_coordinates = ""
# target_coordinates = str(hotel_df["lat"][0])+', '+ str(hotel_df["lon"][0])
# # target_coordinates.append(",") 
# #target_coordinates = hotel_df["lon"][0] 
# print("target_coordinates")
# print(target_coordinates)
# print()

#target_coordinates = '36.6177' + ', ' + '-121.9166'   #worked
print(hotel_df["lat"][0])
print(hotel_df["lon"][0])
target_coordinates = str(hotel_df["lat"][4]) + ', ' + str(hotel_df["lon"][4])
target_coordinates = "41.8921371, -87.6266983"

print("target_coordinates")
print(target_coordinates)
print()

print('*******************************************************88888888888888888888888888888888***')
print('need to add way to glue together the target cooridnate strings and do a try except to skip missing/bad cities')
print('*******************************************************88888888888888888888888888888888***')

# print('hotel_df[["lat", "lon"]]')
# print(hotel_df[["lat", "lon"]])
# target_coordinates = hotel_df[["lat", "lon"]]
# print('target_coordinates[1:2]')
# print(target_coordinates[1:2])


location=target_coordinates
# target_search = "Chinese"
# target_radius = 8000
# target_type = "restaurant"
target_search = "Marriott"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
# params = {
#     "location": target_coordinates,
#     "keyword": target_search,
#     "radius": target_radius,
#     "type": target_type,
#     "key": g_key  #api_keys  #gkey
# }
params = {
    "location": location,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key  #api_keys  #gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in 
# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
print()

# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# target_coordinates
# 43.6187102, -116.2146068
#
# -42.7826
# 147.0587
# target_coordinates
# 41.8921371, -87.6266983
#
# *******************************************************88888888888888888888888888888888***
# need to add way to glue together the target cooridnate strings and do a try except to skip missing/bad cities
# *******************************************************88888888888888888888888888888888***
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEArZ-2IxioGtF_z7TXEFxSJgoC5eiOL4Ktxt6yBD8tQBjXpUTrvnRTm0UDbR1tPKJGQTOyytqGM6u3Y_HiHeVxjmVMsm2z2BQOP5Dcq7E8DA8wqOarE-oLg07apNEg0xzxKvZYyCkOdU6sCeWFXBR81lZ-gaGO07kyBunqQIi6idCeHPwu6zziJR1uNvPhZqyHWpOzJozBVFRmBhQTkjylFfAbfjad6JZYB4B9T7JgSEOZ32fmeF-xoxaATB-KEzmEmfjagDI54DAN4PolzsYSQWr44_5O_xySvDov1FR4HSX0DNo5OT1PCq0e9u0XdRsBvja9FYsD-LgVL6b3ZpKVLOK6R5AJCWnaLX1QfR2PgjWUC9nZyw9IhAdpcUhxGOTPScEATMp7BIc89kiLL3xIRegU4VtNRaDYDPsP3iL6bJKrE7aRy2mweC_X-ZW6TPkk78A",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8921331,
#                     "lng": -87.6245096
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89358932989271,
#                         "lng": -87.62348352010729
#                     },
#                     "southwest": {
#                         "lat": 41.89088967010726,
#                         "lng": -87.62618317989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Chicago Marriott Downtown Magnificent Mile",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110559584681310635880\">Chicago Marriott Downtown Magnificent Mile</a>"
#                     ],
#                     "photo_reference": "Aap_uEBT_uEju04gPxnc90JxnlWz4mdPZPprpSwugB_DMmkD982yVYQCsh4AszeY3mavxDi_jJqKAUeLIrspeOzUUsqjf0eyGtTDfqfX4LD-wApOizGz7rzjLmUONjevOybgQOrmvyXHcIgrJewuCRxqllUyxL-yl-xbB17gq3exJrCiZbM",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJw0-xW6wsDogRI8-Iesq9Y9A",
#             "plus_code": {
#                 "compound_code": "V9RG+V5 Chicago, Illinois",
#                 "global_code": "86HJV9RG+V5"
#             },
#             "rating": 4.3,
#             "reference": "ChIJw0-xW6wsDogRI8-Iesq9Y9A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2752,
#             "vicinity": "540 Michigan Ave, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8793371,
#                     "lng": -87.6328322
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.88060007989272,
#                         "lng": -87.63121742010728
#                     },
#                     "southwest": {
#                         "lat": 41.87790042010728,
#                         "lng": -87.63391707989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "JW Marriott Chicago",
#             "photos": [
#                 {
#                     "height": 256,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107865340731354656278\">JW Marriott</a>"
#                     ],
#                     "photo_reference": "Aap_uECmkd-p1HZGjpq1XrHia1EutWOo8hrvH_yCyZJPx-ecIzVPnkIt0tTJtX7jEfpjugfpfgK30ceaimyC_8fQFJ2oJxH2bDN9F3ZKfQbKGvOvZSuVmYjA2NLnvmDikwqeZZ1yR-13Uusz9mV62rrv4jb0q9yHazf3-0RMmOyz2Cb98f_-",
#                     "width": 383
#                 }
#             ],
#             "place_id": "ChIJESf9FrwsDogRg9RZOPtiZp8",
#             "plus_code": {
#                 "compound_code": "V9H8+PV Chicago, Illinois",
#                 "global_code": "86HJV9H8+PV"
#             },
#             "rating": 4.5,
#             "reference": "ChIJESf9FrwsDogRg9RZOPtiZp8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2285,
#             "vicinity": "151 W Adams St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8540186,
#                     "lng": -87.6205363
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.85485432989272,
#                         "lng": -87.61891912010728
#                     },
#                     "southwest": {
#                         "lat": 41.85215467010728,
#                         "lng": -87.62161877989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Marriott Marquis Chicago",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105400984221315344987\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBkIYOBypiO6L5Jl7e12iHJA70b365QeR9QKyJ_aH6MTJDcePDvQEGAtD9NYtBYd4mXmXFNakEAzUznbxiAo4IWUPqhUlyi5FAp1JPpg0rvmTlqRl2RGNNeqRQ6QYEa-KXd3yBhmryQN5IZf9dHecgEY5JRU_kR0EOy4gmLc-9zx4E",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJE9zmrn8sDogRzRWC-IetMTQ",
#             "plus_code": {
#                 "compound_code": "V93H+JQ Chicago, Illinois",
#                 "global_code": "86HJV93H+JQ"
#             },
#             "rating": 4.6,
#             "reference": "ChIJE9zmrn8sDogRzRWC-IetMTQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2418,
#             "vicinity": "2121 S Prairie Ave, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8932283,
#                     "lng": -87.6229367
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89454897989272,
#                         "lng": -87.62147267010728
#                     },
#                     "southwest": {
#                         "lat": 41.89184932010728,
#                         "lng": -87.62417232989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Courtyard by Marriott Chicago Downtown/Magnificent Mile",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108121417747464747239\">Courtyard Chicago Downtown/Magnificent Mile</a>"
#                     ],
#                     "photo_reference": "Aap_uEBWPRlhB54YZEdX0wGeUMNi_6w_DnEnfTOVtd4AWftUm22kvcgcw_42UpA_4Mmjf2Pq1vwEEsBIPN73Dd-alJqiuH0NM2nN_7obVpD3ZsvNmsVzvSGwgl4LX0WfAuRWEt_q2hnhDXT5bGeoanCJBCVrTOJfYSTmzLffZASzZtievSie",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJyfdSZassDogRiKuPYX_1iok",
#             "plus_code": {
#                 "compound_code": "V9VG+7R Chicago, Illinois",
#                 "global_code": "86HJV9VG+7R"
#             },
#             "rating": 4.4,
#             "reference": "ChIJyfdSZassDogRiKuPYX_1iok",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1443,
#             "vicinity": "165 E Ontario St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8902076,
#                     "lng": -87.6275928
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89182687989272,
#                         "lng": -87.62644762010729
#                     },
#                     "southwest": {
#                         "lat": 41.88912722010728,
#                         "lng": -87.62914727989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Courtyard by Marriott Chicago Downtown/River North",
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105105515163618239529\">Courtyard Chicago Downtown/River North</a>"
#                     ],
#                     "photo_reference": "Aap_uEBdnbSpVF-xuv2g_C77_8oBSGjN90Rgn53UcxH_PvidXCCFRQdPpMORUnfKvZQLJ4S7i-H1_XpgY9IQr6MAl403uay-flPt3pBQCvY4zSeFOmmbr_GSc_z5AZlDUNKfkgoi47hCR-2Ui0fgLgqDiv0DsUcEtLsyOZ2J--RVRVgpIWL_",
#                     "width": 1366
#                 }
#             ],
#             "place_id": "ChIJc-o6Cq4sDogR8hdfRQmp_WY",
#             "plus_code": {
#                 "compound_code": "V9RC+3X Chicago, Illinois",
#                 "global_code": "86HJV9RC+3X"
#             },
#             "rating": 4.3,
#             "reference": "ChIJc-o6Cq4sDogR8hdfRQmp_WY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1492,
#             "vicinity": "30 E Hubbard St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8494306,
#                     "lng": -87.63172039999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.85076552989272,
#                         "lng": -87.63048117010727
#                     },
#                     "southwest": {
#                         "lat": 41.84806587010728,
#                         "lng": -87.63318082989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "SpringHill Suites by Marriott Chicago Chinatown",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110647800102715166497\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEByEFaIq7m79VNbYHgLHMrYMhdlo8kqPomH1DeFN406WEQXjTwY_Ov3oun0_UJiOzELrDb15R5SRsgdSFYtG_fqkczVQ7q4cNDQfydwPlpQnjv-TcE07aE8gkEe80MIiNBH0ef9n6GDGeiWvXxMdmTWYPzG3I8KW3OVl702Q-dwPuZB",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJPSYJ0LItDogRh50OHlZWqzg",
#             "plus_code": {
#                 "compound_code": "R9X9+Q8 Chicago, Illinois",
#                 "global_code": "86HJR9X9+Q8"
#             },
#             "rating": 4.6,
#             "reference": "ChIJPSYJ0LItDogRh50OHlZWqzg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 119,
#             "vicinity": "2357 S Wentworth Ave, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8895711,
#                     "lng": -87.6299143
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89096452989271,
#                         "lng": -87.62840667010728
#                     },
#                     "southwest": {
#                         "lat": 41.88826487010727,
#                         "lng": -87.63110632989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Residence Inn by Marriott Chicago Downtown/River North",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103669638933612818620\">Residence Inn Chicago Downtown/River North</a>"
#                     ],
#                     "photo_reference": "Aap_uEB0T8_i01BwPZlHmHx0kSTmhVi3tzQldvRxiCQi2YTau1mNbYhrmpSAeKiB3fJo8tGvGMPzrYIBJK3VBYy5L5SUOt_CJ91vWY9ThL2tJhTuSvMVrtDDZPpmS-PRy1dJN16ANRO19zru89aE1HT-i8p39w-KPHKQsGx5aeFfaEPb4PCU",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJi1l57bEsDogRKhd9_2Gh-a8",
#             "plus_code": {
#                 "compound_code": "V9QC+R2 Chicago, Illinois",
#                 "global_code": "86HJV9QC+R2"
#             },
#             "rating": 4.5,
#             "reference": "ChIJi1l57bEsDogRKhd9_2Gh-a8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1458,
#             "vicinity": "410 N Dearborn St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8897467,
#                     "lng": -87.62989259999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89103287989272,
#                         "lng": -87.62839682010727
#                     },
#                     "southwest": {
#                         "lat": 41.88833322010728,
#                         "lng": -87.63109647989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "SpringHill Suites by Marriott Chicago Downtown/River North",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103128586109471176458\">SpringHill Suites Chicago Downtown/River North</a>"
#                     ],
#                     "photo_reference": "Aap_uECMThnrzn_tnMlb3A-xLasO9XVz1BR_Df3qI9J1LtMQYV1Bb2oII8pwiZG1t43Rar64hHXNBp1xZlEx8REx2pEHIZxcmPTBq9mgwKDkZjXzHW-ZKj9hNpmh0eXW3mfGZy4GRcnozJdtMetgzczhYYkwBzUI-QGf08rwg8QwRLK_WTC7",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJi1l57bEsDogRU7g2cylztE4",
#             "plus_code": {
#                 "compound_code": "V9QC+V2 Chicago, Illinois",
#                 "global_code": "86HJV9QC+V2"
#             },
#             "rating": 4.4,
#             "reference": "ChIJi1l57bEsDogRU7g2cylztE4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1238,
#             "vicinity": "410 N Dearborn St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8815897,
#                     "lng": -87.63210029999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.88311777989273,
#                         "lng": -87.63087827010727
#                     },
#                     "southwest": {
#                         "lat": 41.88041812010728,
#                         "lng": -87.63357792989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Residence Inn Chicago Downtown/Loop",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110377447319661806825\">Residence Inn Chicago Downtown/Loop</a>"
#                     ],
#                     "photo_reference": "Aap_uEDv0b7cHmQlQoFN1y_TuGejK7-aLJD_yFgr1Mv5uD8y_rz1SGF0fV4dbA8q1Qp1_YmPwr6Qaz9pEl3rgMfxUAG4Tosr1F_RZ5H6JpQIOzmJqteu0LPA_-25rNEpgwAQlZ6UBdMrUvcyw6TYTyoBRy3x0sy6QFDPLcfrEqw8OlIVMOG_",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJafCZ6bssDogRvV_QMyh_5cA",
#             "plus_code": {
#                 "compound_code": "V9J9+J5 Chicago, Illinois",
#                 "global_code": "86HJV9J9+J5"
#             },
#             "rating": 4.6,
#             "reference": "ChIJafCZ6bssDogRvV_QMyh_5cA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1668,
#             "vicinity": "11 S LaSalle St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.893655,
#                     "lng": -87.621918
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89486327989272,
#                         "lng": -87.62056792010728
#                     },
#                     "southwest": {
#                         "lat": 41.89216362010728,
#                         "lng": -87.62326757989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Fairfield Inn & Suites by Marriott Chicago Downtown/Magnificent Mile",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112488453757299311246\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEAYqU0JIr9SxffHbyFVUAbLHrriavTovyNw693VGmEWxFfsyqxZyJlfh-BcVnkwg8tf4yeUDgdY1S-TpBlbopcV4SHb_24BKKxbj8p_6HSKKuR6kakBrspibMMHzds7KOMITk2l04fecMlnZnrcDZZ2SsZ5nVJ_UdXLcGdfDijYgsDA",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJiVgEEassDogRj4b-RT3WveQ",
#             "plus_code": {
#                 "compound_code": "V9VH+F6 Chicago, Illinois",
#                 "global_code": "86HJV9VH+F6"
#             },
#             "rating": 4.3,
#             "reference": "ChIJiVgEEassDogRj4b-RT3WveQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1080,
#             "vicinity": "216 E Ontario St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.89326579999999,
#                     "lng": -87.6211095
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89467972989272,
#                         "lng": -87.61975132010728
#                     },
#                     "southwest": {
#                         "lat": 41.89198007010727,
#                         "lng": -87.62245097989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Aloft Chicago Mag Mile",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104240448082023744924\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBHjo-W3aqd9kjyFnXkxod2qmwnBI-tpF1tgP1tJA7Us0-v3jZ3FoQ0_nl-K2TfGowS3EDQVA6l_5Vy1Ai2UGInLdmqiPnzyjdFUnKqANian5QKoTvM0HyKamfme80EYgubU8_bIukhIOcm0M-ZF9R0B7DpuQ1qsi4pJ89IsiB-vYBZ",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJPwM6b2UtDogRnb2Pk8xjtYY",
#             "plus_code": {
#                 "compound_code": "V9VH+8H Chicago, Illinois",
#                 "global_code": "86HJV9VH+8H"
#             },
#             "rating": 4.2,
#             "reference": "ChIJPwM6b2UtDogRnb2Pk8xjtYY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 760,
#             "vicinity": "243 E Ontario St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8738158,
#                     "lng": -87.6659938
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.87516277989272,
#                         "lng": -87.66489597010728
#                     },
#                     "southwest": {
#                         "lat": 41.87246312010728,
#                         "lng": -87.66759562989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Chicago Marriott at Medical District/UIC",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112473023305028496988\">Chicago Marriott at Medical District/UIC</a>"
#                     ],
#                     "photo_reference": "Aap_uED1u-5ccOIenaNVKbBn8XcEgxSC2HR_xtsWP6jSWw1-QWnHYuws_WK_4GI4ElWTB-k2E4pdz-IDQNjkuZVl4ubNA0xyfByv82x9ohiFYUJHo058hEZFTjz5KtlZRkDIXY4ZfuSPmsW-sdFuI9Y8HjXLgGbZuV-_P3_MMGZHE1M9-HqR",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJy1ncrBktDogRrwlCKOfflC8",
#             "plus_code": {
#                 "compound_code": "V8FM+GJ Chicago, Illinois",
#                 "global_code": "86HJV8FM+GJ"
#             },
#             "rating": 4.2,
#             "reference": "ChIJy1ncrBktDogRrwlCKOfflC8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 662,
#             "vicinity": "625 South Ashland Avenue At, W Harrison St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.89100579999999,
#                     "lng": -87.63072299999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89227317989272,
#                         "lng": -87.62923622010727
#                     },
#                     "southwest": {
#                         "lat": 41.88957352010728,
#                         "lng": -87.63193587989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Fairfield Inn & Suites by Marriott Chicago Downtown/River North",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115731007232239935911\">Fairfield Inn &amp; Suites Chicago Downtown/River North</a>"
#                     ],
#                     "photo_reference": "Aap_uEDQYKVEK1OfYH1V3_02LRKlBZD0PjTku8d2REJxqLVxHkurnCIw-_HN1Ca4AYwrmnIS4z_59GO8Xutw-chr3qUHEGwx0m4RKyOF21cvj1uY5btwj_3nW_BBom7j1ikSFVvZZD1Di4VfLnqjtJhu5BTAssp8sWIHD9lTjHWzJNqLd7Tz",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJJZMpMLIsDogRdLYZQFkybko",
#             "plus_code": {
#                 "compound_code": "V9R9+CP Chicago, Illinois",
#                 "global_code": "86HJV9R9+CP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJJZMpMLIsDogRdLYZQFkybko",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 972,
#             "vicinity": "60 W Illinois St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8936383,
#                     "lng": -87.62608809999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89498927989272,
#                         "lng": -87.62440657010728
#                     },
#                     "southwest": {
#                         "lat": 41.89228962010728,
#                         "lng": -87.62710622989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "AC Hotel Chicago Downtown",
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102125514675422487491\">AC Hotel Chicago Downtown</a>"
#                     ],
#                     "photo_reference": "Aap_uEBhABiXKa-J_U9hpmfPKJCuUOc_Iz-sctR0RDWcVCyiapGM68tBwfSBIyqX9i5U-EnyjUTgyCV9pU4117alBVHK0SeWePffHFTqaE6PVwS6VEdFYAqlU2bqyARPFimA6ED8Qry-2-ipzOLzJx-xroA8O3NOPEk8WLN4hIm6vX9oOIXk",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJnYPf5qwsDogR2WFyOA2yCjA",
#             "plus_code": {
#                 "compound_code": "V9VF+FH Chicago, Illinois",
#                 "global_code": "86HJV9VF+FH"
#             },
#             "rating": 4.3,
#             "reference": "ChIJnYPf5qwsDogR2WFyOA2yCjA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1344,
#             "vicinity": "630 N Rush St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8715546,
#                     "lng": -87.6245789
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.87288037989273,
#                         "lng": -87.62306092010728
#                     },
#                     "southwest": {
#                         "lat": 41.87018072010729,
#                         "lng": -87.62576057989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Le Meridien Essex Chicago",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116798209347834189639\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uECa-iDjqoKdIWEuAmUc1eC-t1WHGA3pTdYVQDev3U5s1zLcHne6aHpPcXmOcG-o0ubQdv3KVdOZ79XvubEJxSGyUuDhi8Yt4dbJq_Sfb3owNj72LY_xhm87PNOkcf76up4mZtXvSwM7P3NjN69MErILX_Hxyk9RQ1sij2HzLKTmLjH_",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJ4SxqR6ItDogRmD1bdg3rOA8",
#             "plus_code": {
#                 "compound_code": "V9CG+J5 Chicago, Illinois",
#                 "global_code": "86HJV9CG+J5"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ4SxqR6ItDogRmD1bdg3rOA8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1890,
#             "vicinity": "800 S Michigan Ave, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8886169,
#                     "lng": -87.62887409999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.88987092989272,
#                         "lng": -87.62746342010726
#                     },
#                     "southwest": {
#                         "lat": 41.88717127010727,
#                         "lng": -87.63016307989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hotel Chicago Downtown, Autograph Collection",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118409452762749186493\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBcMDfD9bIJ5Gf-PBAwLm408NfFNTPQ2C_B8jaPC8NYKn0LA0ofzd3PowroFy_KBTbIFwF4Ti6hJT95_TbHURJt4RlxPS6DDc3-y8mLPGpTVScp88pXaI74m3aKNJSrL6hfKzmK87RVLtkxQtjBRraSwf0pKMvFUG-KFgyH3TJaEvR0",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJJSahIa4sDogRMldNttQifyc",
#             "plus_code": {
#                 "compound_code": "V9QC+CF Chicago, Illinois",
#                 "global_code": "86HJV9QC+CF"
#             },
#             "rating": 4.4,
#             "reference": "ChIJJSahIa4sDogRMldNttQifyc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2274,
#             "vicinity": "333 N Dearborn St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8862002,
#                     "lng": -87.62831290000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.88768627989273,
#                         "lng": -87.62694802010728
#                     },
#                     "southwest": {
#                         "lat": 41.88498662010728,
#                         "lng": -87.62964767989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Renaissance Chicago Downtown Hotel",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115710852742050292557\">Renaissance Chicago Downtown Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEBjTYV2L4KjpYgJsAawVrerAi0odn6Uaq6yZi0ENc66Xh5cW_pA0UpmH3FYh0dPi-vDML60TXWAnQOWiOKEJa41ndXIrhcIKAb6LUPx2OsMy697O94L6mNiczoUf2_fVdgOHDFeE_cSiCYOYvZkOjx2sqZqWg92q0Q0AfQIdCZ-_PVI",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJeXUiILAsDogRFNdo6Iq27oo",
#             "plus_code": {
#                 "compound_code": "V9PC+FM Chicago, Illinois",
#                 "global_code": "86HJV9PC+FM"
#             },
#             "rating": 4.5,
#             "reference": "ChIJeXUiILAsDogRFNdo6Iq27oo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2564,
#             "vicinity": "1 W Wacker Dr, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8936551,
#                     "lng": -87.6153803
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89508522989272,
#                         "lng": -87.61394582010726
#                     },
#                     "southwest": {
#                         "lat": 41.89238557010727,
#                         "lng": -87.61664547989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "W Chicago - Lakeshore",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111632198750294283420\">W Chicago Lakeshore</a>"
#                     ],
#                     "photo_reference": "Aap_uEC0JAIUurFF_4Y7u2A-tsggWpA9IgTzukCC8BF1FpOui4PRWivQcHaI9qgBKM5Elm9uDdPORMhD7UUTzjOl4b8Yil3sL0TA8i4BbbaIDOUxpuunWQzGaVqU79okGgRivbXNdGfNO3tVMfLF9X_RfwBqmhwP10zQNjZ747mlQSuwLKw9",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJaQfLwlQrDogRg4iiPfEl1J4",
#             "plus_code": {
#                 "compound_code": "V9VM+FR Chicago, Illinois",
#                 "global_code": "86HJV9VM+FR"
#             },
#             "rating": 4.2,
#             "reference": "ChIJaQfLwlQrDogRg4iiPfEl1J4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2985,
#             "vicinity": "644 N Lake Shore Dr, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8880493,
#                     "lng": -87.6298778
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.88959487989273,
#                         "lng": -87.62861862010728
#                     },
#                     "southwest": {
#                         "lat": 41.88689522010728,
#                         "lng": -87.63131827989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "The Westin Chicago River North",
#             "photos": [
#                 {
#                     "height": 1366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104944192827328772876\">The Westin Chicago Northwest</a>"
#                     ],
#                     "photo_reference": "Aap_uEDirOu35cBsjFcUkw4ffVFlPibT85Xsjb8BLPuOCvKoF8IuuviXG4YZHoDEo1fsY2NdoiG1HIZ8Ol_ALf_F4YLDztRmxh_RH8m3-opXZ-hHmnN76TQq9FvK982EVIhIxeliYuQLF38o9CCZ5FI4c29XJQ1UmXe6Rhlmex6ifBac1EdM",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJXZob1gWuD4gRKrOCrK38pDI",
#             "plus_code": {
#                 "compound_code": "V9QC+62 Chicago, Illinois",
#                 "global_code": "86HJV9QC+62"
#             },
#             "rating": 4.4,
#             "reference": "ChIJXZob1gWuD4gRKrOCrK38pDI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1750,
#             "vicinity": "320 N Dearborn St, Chicago"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8891309,
#                     "lng": -87.6193955
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.89068612989272,
#                         "lng": -87.61804802010728
#                     },
#                     "southwest": {
#                         "lat": 41.88798647010728,
#                         "lng": -87.62074767989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Sheraton Grand Chicago",
#             "photos": [
#                 {
#                     "height": 2091,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114117576315254475197\">Sheraton Grand Chicago</a>"
#                     ],
#                     "photo_reference": "Aap_uED3KPh6MZgdIwoH8tSZ7w2H5tp3uDt9-0-GWt5KsJhC8_hi2PHOMaG9tBKdj4UUrENcKsvlYl3nRbiZtOqFDAjW6glBINrmIRFvBfVR6BQWHxXZ1tDeT2Xp7ObKbLQu2FXvJiV_Q-5WvO2e6Rkbh8CxJIee37PP1Xm6USIHxfCFCe-A",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJI8hF76ksDogRoVilbrDda7o",
#             "plus_code": {
#                 "compound_code": "V9QJ+M6 Chicago, Illinois",
#                 "global_code": "86HJV9QJ+M6"
#             },
#             "rating": 4.3,
#             "reference": "ChIJI8hF76ksDogRoVilbrDda7o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5066,
#             "vicinity": "301 E North Water St, Chicago"
#         }
#     ],
#     "status": "OK"
# }
#
# Chicago Marriott Downtown Magnificent Mile
# 540 Michigan Ave, Chicago

# %%
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Monterey Marriott
# 350 Calle Principal, Monterey

# %%
print(hotel_df)
#df.rename(columns={"A": "a", "B": "c"})
hotel_df.rename(columns={"city": "City", "lat": "Lat", "lon": "Lng"},inplace=True)

#hotel_df
hotel_df
print("hotel_df")
print(hotel_df)
# Out:
#    index           city      lat       lon   temp  TempMax  Humidity  \
# 0      0    new norfolk -42.7826  147.0587  19.96    22.64        38
# 1      1        mataura -46.1927  168.8643  23.44    23.44        55
# 2      7      mahajanga -15.7167   46.3167  26.01    26.01        94
# 3      8   port lincoln -34.7333  135.8667  21.01    21.01        56
# 4      9  pacific grove  36.6177 -121.9166  14.58    17.12        51
#
#    Cloudiness  Wind Speed Hotel Name
# 0           7        1.34
# 1          18        2.45
# 2          40        2.06
# 3          13        6.46
# 4           0        2.06
#    index           City      Lat       Lng   temp  TempMax  Humidity  \
# 0      0    new norfolk -42.7826  147.0587  19.96    22.64        38
# 1      1        mataura -46.1927  168.8643  23.44    23.44        55
# 2      7      mahajanga -15.7167   46.3167  26.01    26.01        94
# 3      8   port lincoln -34.7333  135.8667  21.01    21.01        56
# 4      9  pacific grove  36.6177 -121.9166  14.58    17.12        51
#
#    Cloudiness  Wind Speed Hotel Name
# 0           7        1.34
# 1          18        2.45
# 2          40        2.06
# 3          13        6.46
# 4           0        2.06
# hotel_df
#    index           City      Lat       Lng   temp  TempMax  Humidity  \
# 0      0    new norfolk -42.7826  147.0587  19.96    22.64        38
# 1      1        mataura -46.1927  168.8643  23.44    23.44        55
# 2      7      mahajanga -15.7167   46.3167  26.01    26.01        94
# 3      8   port lincoln -34.7333  135.8667  21.01    21.01        56
# 4      9  pacific grove  36.6177 -121.9166  14.58    17.12        51
#
#    Cloudiness  Wind Speed Hotel Name
# 0           7        1.34
# 1          18        2.45
# 2          40        2.06
# 3          13        6.46
# 4           0        2.06
# C:\Users\BZ Northwestern BC\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\BZNORT~1\AppData\Local\Temp/ipykernel_2952/1108349961.py in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# C:\Users\BZNORT~1\AppData\Local\Temp/ipykernel_2952/1108349961.py in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'Country'

# %%
# Add marker layer ontop of heat map

# Create a list containing coordinates
# coordinates = [
#     (40.71, -74.00),
#     (30.26, -97.74),
#     (46.87, -96.78),
#     (47.60, -122.33),
#     (32.71, -117.16)
#     ]

print('hotel_df[["lat", "lon"]]')
print(hotel_df[["lat", "lon"]])
coordinates = hotel_df[["lat", "lon"]]

# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)  # Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
# Save the figure
plt.savefig("output_data/vacation_markers.png")

# Display figure
fig
